# %%
# Out:
# hola mundo

# %%
#challenge 1
nombre = "Liz Mariel Sanabria Gaona"  #para crear las variables no se usan numeros o espacios
edad = 24
ciudad = "San Lorenzo" 
print(nombre, edad, ciudad)
# Out:
# Liz Mariel Sanabria Gaona 24 San Lorenzo

# %% [markdown]
# #operadores
# // --> division exacta.
# %

# %%
#challenge2
#suma
cantidad_de_manzanas = 10
cantidad_de_naranjas = 5
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print("La cantidad de frutas inicial es", cantidad_de_frutas)

#resta
frutas_vendidas = 6
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print("La cantidad de frutas restantes es", frutas_restantes)
# Out:
# La cantidad de frutas inicial es 15
# La cantidad de frutas restantes es 9

# %%
#challenge3
nombre = "Luz"
apellido = "Quiñonez"
# print("Hola. Me llamo " + nombre + " " + apellido + "."+ " " + "Mucho gusto") #se puede usar f para concatenar
print(f"Hola. Me llamo {nombre} y mi apellido es {apellido}")
# Out:
# Hola. Me llamo Luz y mi apellido es Quiñonez

# %%
#challenge3
#El input sirve para solicitar informacion al usuario. 
#int sirve para cambiar la variable string(cadena) a un numero entero 

numero1 = int(input("Ingrese un numero"))
numero2 = int(input("Ingrese un segundo numero"))
suma = numero1 + numero2
print("La suma de los dos numeros es", suma)
# Out:
# La suma de los dos numeros es 4

# %%
#definir funciones
def preparar_sandwich():
    print("Preparando el sandwich")
    print("El sandwich esta listo")     

preparar_sandwich()
# Out:
# Preparando el sandwich
# El sandwich esta listo

# %%
#proceso de preparacion de arroz
def preparar_arroz():
    print("Lavar el arroz")
    print("Colocar el arroz en la olla u otro recipiente")
    print("Cocinar el arroz")
    print("Disfrutar el arroz :)")

preparar_arroz()
preparar_arroz()
preparar_arroz()
# Out:
# Lavar el arroz
# Colocar el arroz en la olla u otro recipiente
# Cocinar el arroz
# Disfrutar el arroz :)
# Lavar el arroz
# Colocar el arroz en la olla u otro recipiente
# Cocinar el arroz
# Disfrutar el arroz :)
# Lavar el arroz
# Colocar el arroz en la olla u otro recipiente
# Cocinar el arroz
# Disfrutar el arroz :)

# %% [markdown]
# ## Challenge 🤺 - 25m
#
# Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas.

# %%
#challenge 5
pregunta = input("¿Que caracteristicas tiene el mouse a comprar?")

x = "logitech"
y = "negro"
def pregunta_al_usuario(preg,marca,color):
    print(f"El usuario pregunta que: {preg}, solicita un mouse de la marca: {marca} y del color: {color}")

pregunta_al_usuario(pregunta,x,y)

#challenge 5
pregunta = input("¿Que caracteristicas tiene el mouse a comprar?")

x = "logitech"
y = "negro"
def pregunta_al_usuario(preg,marca,color):
    print(f"El usuario pregunta que: {preg}, solicita un mouse de la marca: {marca} y del color: {color}")

pregunta_al_usuario(pregunta,x,y)
# Out:
# El usuario pregunta que: negro, solicita un mouse de la marca: logitech y del color: negro

# %% [markdown]
#  Objetivo:
# Escribir una función que pregunte por las características de un producto a comprar (por ejemplo, tipo, tamaño, color) e imprima un resumen de ese producto con las características ingresadas.
#
# Además, deben trabajar con variables locales y globales.

# %%
producto = input("¿Que tipo de producto desea comprar?")
tamaño = input("¿Cual es el tamaño del producto?")
color = input("Ingrese el color del producto")

def func_mostrar(x,y,z):
    print(f"El producto requerico es {x},el tamaño es {y}, el color es {z}")

func_pregunta(producto, tamaño, color)

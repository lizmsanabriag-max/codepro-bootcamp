# %%
print("hola")
# Out:
# hola

# %% [markdown]
# Challenge - 15m,
# Escribe un programa que pregunte al usuario por su edad y determine si tiene edad suficiente para comprar y consumir alcohol.
# Si el usuario tiene mas de 18 pero menos de 21 impirmir "Podes tomar pero no comprar",
# Si el usuario tiene menos de 18 imprimir "Juguito nomas",
# Si el usuario tiene mas de 21 imprimir "Hace lo que quieras"

# %%
#challenge 1 -condicionales
# > mayor, < menor, > = mayor o igual, <= menor a igual, == igual, =! diferente
edad = int(input("Ingrese su edad"))  #paso 1: pregunta (se almacena en edad)
if edad >= 18: 
    print("Podes tomar pero no comprar")
elif edad < 21:
  print("Podes tomar pero no comprar")
elif edad > 21:
  print("Hace lo que quieras")
else:
 print("Juguito nomas")
# Out:
# Podes tomar pero no comprar

# %% [markdown]
# Escribir un programa en el que se pregunte al usuario por una temperatura (en grados Celsius), imprima la temperatura escrita, y luego clasificar la temperatura ingresada en los siguientes niveles:
#
# Entre -10 y 18 grados, que imprima "Fresquete".,
# Entre 19 y 30 grados, que imprima "Calor'i".,
# Entre 31 y 45 grados, que imprima "Hakuuuuuu".,
# Para todo lo demás, imprimir "Ñamano mba'e!".

# %%
#challenge2:
temperatura = int(input("Ingrese la temperatura")) #paso 1: obtener dato de temp
print("La temperatura ingresada es", temperatura)  #paso 2: se muestra la temperatura
#paso 3: condicionales
#condicional 1: 
if temperatura  >= -10 and temperatura <= 18:
 print("Fresquete")
elif temperatura >= 19 and temperatura <= 30:
 print("Calor'i")
elif temperatura >= 31 and temperatura <= 45:
 print("Hakuuuuu")
else:
 print("Ñamanomba")
# Out:
# La temperatura ingresada es 28
# Calor'i

# %% [markdown]
# Challenge  - 15m,
# Escribir un programa que almacene una contraseña en una variable, y pregunte al usuario por la contraseña hasta que introduzca la contraseña correcta.
#
# Cuando el usuario ingrese la contrasena correcta, imprimir un mensaje secreto.

# %%
contraseña_correcta = "lenteja"
contraseña_usuario = input("Ingrese una contraseña")

while contraseña_usuario != contraseña_correcta:
 contraseña_usuario = input("Ingrese una contraseña")
 if contraseña_usuario == contraseña_correcta:
     print("Has ingresado la contraseña correcta")
     break
# Out:
# Has ingresado la contraseña correcta

# %% [markdown]
# Challenge  - 10m,
# Crear una lista de 5 elementos. Luego, seguir los siguientes pasos.
#
# Agregar un elemento al final de la lista.,
# Modificar el segundo elemento,
# Eliminar el tercer elemento.

# %%
#challenge 4: definir listas
lista_de_ropa = ["jeans", "remera", "chaqueta", "short", "bermuda"]
lista_de_ropa.append("vestido")
print(lista_de_ropa)
lista_de_ropa[2] = "Hoodie"
print(lista_de_ropa)
lista_de_ropa.pop(2)
print(lista_de_ropa)
# Out:
# ['jeans', 'remera', 'chaqueta', 'short', 'bermuda', 'vestido']
# ['jeans', 'remera', 'Hoodie', 'short', 'bermuda', 'vestido']
# ['jeans', 'remera', 'short', 'bermuda', 'vestido']

# %% [markdown]
# Challenge 🤺 - 15m
# Escribir un programa que itere en un rango de 10 veces. Por cada iteracion multiplicar el iterador por dos e imprimir el resultado.

# %%
#challenge 5: usar iterador
for i in range(10): 
 multiplicacion = i*2
 print(multiplicacion)

# %%
#challenge 6: recorrer los elementos de una lista de marca e imprimir cada marca solamente si tiene 6 letras o mas.
lista_de_marcas = ["rare beauty", "sephora", "OG", "Maybelin", "Ruby Rose", "Fenty"]
for marcas in lista_de_marcas:                #recorrer la lista 
     print(len(marcas)) #nos da la cantidad de caracteres en cada elemento
     cantidad_de_letras = (len(lista_de_marcas)) #como guardar el elemento que tiene 6 letras en una variable
     if cantidad_de_letras >= 6: 
       print(cantidad_de_letras)

# %% [markdown]
# Challenge  - 10m,
# Solicitar al usuario que ingrese una frase.
#
# Imprimir un mensaje cada vez que se encuentre una letra "o".

# %%
#challenge7: 
mensaje_usuario = input("Ingrese un mensaje") #solicitar mensaje
condicion = "o" 
for letra in mensaje_usuario:
     if letra == condicion:
        print("Se ha encontrado la letra o en el mensaje")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 6
#       4 for letra in mensaje_usuario:
#       5      if letra == condicion:
# ----> 6         print(f"Se ha encontrado la letra o en", [mensaje])
#
# NameError: name 'mensaje' is not defined
